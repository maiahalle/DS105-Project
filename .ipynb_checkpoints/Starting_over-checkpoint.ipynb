# %% [markdown]
# ### What I need to do is:
# - Make a list of republican handles and democrat handles from reptweets.csv
# - Use the lists to split df_word_count into a seperate word count dataframe for each party
# - Make visualisations based on each dataframe

# %%
import pandas as pd

# %%
acct_file = "reptweets.csv"
word_count_filename = "word_count.csv"
df_politicians = pd.read_csv(acct_file)
# csv file has trailing spaces on some column names, this insures there are no leading or trailing spaces
df_politicians.columns = df_politicians.columns.str.strip()
df_word_count = pd.read_csv(word_count_filename, low_memory=False)
# combines the two dataframes joining on the common handle column
df_party_word_count = pd.merge(df_politicians, df_word_count, how='inner', on='handle')
# get republicans
df_reps = df_party_word_count[df_party_word_count.party == 'R']
df_dems = df_party_word_count[df_party_word_count.party == 'D']
# get independants but only return the columns Word and Count
df_dem_words = df_party_word_count[df_party_word_count.party == 'D'][['Word', 'Count']]
df_rep_words = df_party_word_count[df_party_word_count.party == 'R'][['Word', 'Count']]

# %%
df_dem_sorted = df_dem_words.groupby(['Word']).sum().sort_values(by=["Count"], ascending = False)

# %%
df_dem_sorted.to_csv('C:/Users/Amara/Documents/GitHub/DS105-Project/democrat_word_counts.csv')

# %%
df_rep_sorted = df_rep_words.groupby(['Word']).sum().sort_values(by=["Count"], ascending = False)

# %%
df_rep_sorted.to_csv('C:/Users/Amara/Documents/GitHub/DS105-Project/republican_word_counts.csv')

# %%
df_democrats = pd.read_csv('democrat_word_counts.csv')

# %%
df_democrats.head(50)
# Out:
#          Word   Count
# 0       today  106447
# 1        work   96303
# 2        more   90738
# 3         act   77729
# 4        need   76149
# 5   community   75110
# 6        make   74090
# 7        help   74039
# 8      family   72546
# 9        year   63444
# 10        get   62177
# 11     health   58538
# 12    support   51900
# 13       pass   50680
# 14     people   50475
# 15      thank   47934
# 16        day   47866
# 17      right   46461
# 18       time   45974
# 19       bill   45366
# 20        now   42683
# 21       join   41414
# 22   american   40585
# 23       vote   39417
# 24       care   38835
# 25    protect   38782
# 26   continue   35974
# 27      fight   35326
# 28        new   34311
# 29  americans   33508
# 30       take   32749
# 31      house   31413
# 32      proud   31166
# 33   congress   30876
# 34    country   30443
# 35       life   30051
# 36       here   28867
# 37      trump   24363
# 38  president   23624
# 39     ensure   20600
# 40      state   20163
# 41      woman   19551
# 42      great   17192
# 43       keep   17076
# 44       just   16333
# 45        law   16183
# 46      honor   15954
# 47         so   15950
# 48        see   15911
# 49    service   15637

# %%
df_republicans = pd.read_csv('republican_word_counts.csv')

# %%
df_republicans.head(50)
# Out:
#               Word  Count
# 0            biden  71400
# 1            today  70940
# 2             more  68580
# 3             work  53997
# 4            thank  52027
# 5             year  46845
# 6         american  46818
# 7             need  41374
# 8            great  41157
# 9             make  40830
# 10       president  38185
# 11            bill  37704
# 12          family  36472
# 13             day  35421
# 14          border  34900
# 15            join  33672
# 16         support  33336
# 17       americans  33196
# 18            help  33010
# 19            time  31570
# 20          people  29686
# 21           house  29139
# 22             act  29038
# 23             get  27906
# 24       community  27411
# 25       democrats  26805
# 26             new  25609
# 27        continue  25506
# 28             now  24088
# 29           state  23903
# 30            here  23625
# 31         america  23274
# 32            life  19828
# 33         country  19402
# 34          nation  19385
# 35            take  19259
# 36        business  18123
# 37            week  17966
# 38             see  17733
# 39          energy  17584
# 40           honor  17091
# 41        congress  16588
# 42           proud  14376
# 43             job  13311
# 44          crisis  13099
# 45         service  12795
# 46            just  12714
# 47         discuss  12253
# 48  administration  12159
# 49        national  11885

# %%
from plotnine import *

# %%
g_democrats = (
    ggplot(df_democrats.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_democrats
# Out:
# <ggplot: (146320625300)>

# %%
g_republicans = (
    ggplot(df_republicans.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_republicans
# Out:
# <ggplot: (146321337447)>

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS

# %%
dtext = " ".join(i for i in df_democrats.Word)
dwordcloud = WordCloud(background_color="white", scale=3).generate(dtext)
plt.figure( figsize=(15,10))
plt.imshow(dwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('democrats_word_cloud.png')

# %%
rtext = " ".join(i for i in df_republicans.Word)
rwordcloud = WordCloud(background_color="white", scale=3).generate(rtext)
plt.figure( figsize=(15,10))
plt.imshow(rwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('republicans_word_cloud.png')

# %%
df_politicians.head()
# Out:
#                   name           handle state party  branch
# 0       Baldwin, Tammy   SenatorBaldwin    WI     D  Senate
# 1       Barrasso, John  SenJohnBarrasso    WY     R  Senate
# 2   Bennet, Michael F.    SenatorBennet    CO     D  Senate
# 3    Blackburn, Marsha  MarshaBlackburn    TN     R  Senate
# 4  Blumenthal, Richard    SenBlumenthal    CT     D  Senate

# %%
df_word_count.head()
# Out:
#             handle     Word  Count
# 0  AustinScottGA08    today    496
# 1  AustinScottGA08    thank    361
# 2  AustinScottGA08  georgia    292
# 3  AustinScottGA08      day    276
# 4  AustinScottGA08     more    274

# %%
df_party_word_count.head()
# Out:
#              name          handle state party  branch       Word  Count
# 0  Baldwin, Tammy  SenatorBaldwin    WI     D  Senate  wisconsin    934
# 1  Baldwin, Tammy  SenatorBaldwin    WI     D  Senate       work    846
# 2  Baldwin, Tammy  SenatorBaldwin    WI     D  Senate    support    618
# 3  Baldwin, Tammy  SenatorBaldwin    WI     D  Senate       need    532
# 4  Baldwin, Tammy  SenatorBaldwin    WI     D  Senate     health    482

# %%
with_dates = pd.read_csv('all_tweets.csv')

# %%
with_dates.tail()
# Out:
#             handle               name             tweet_id   author_id lang  \
# 25  RepPeteAguilar  Rep. Pete Aguilar  1599432082735779840  3018670151   en
# 26  RepPeteAguilar  Rep. Pete Aguilar  1598776424617242624  3018670151   en
# 27  RepPeteAguilar  Rep. Pete Aguilar  1598769566229766145  3018670151   en
# 28  RepPeteAguilar  Rep. Pete Aguilar  1598357144159617026  3018670151   en
# 29  RepPeteAguilar  Rep. Pete Aguilar  1598337669515419649  3018670151   en
#
#              replied_to                created_at  \
# 25  1599432082735779840  2022-12-04T15:54:59.000Z
# 26  1598776424617242624  2022-12-02T20:29:38.000Z
# 27  1598769566229766145  2022-12-02T20:02:22.000Z
# 28  1598357144159617026  2022-12-01T16:43:33.000Z
# 29  1598337669515419649  2022-12-01T15:26:10.000Z
#
#                                            tweet_text  possibly_sensitive  \
# 25  RT @FaceTheNation: For the first time in more ...               False
# 26  My statement with @RepJeffries and @RepKClark ...               False
# 27  Today we mark the 7th anniversary of the deadl...               False
# 28  My statement on the election of @RepJoeNeguse,...               False
# 29  My statement on the election of @WhipClyburn a...               False
#
#         conversation_id                                      key_word_list
# 25  1599432082735779840  ['rt', 'first', 'time', 'more', 'decade', 'hou...
# 26  1598776424617242624           ['statement', 'condemn', 'antisemitism']
# 27  1598769566229766145  ['today', 'mark', 'anniversary', 'deadly', 'te...
# 28  1598357144159617026  ['statement', 'election', 'chair', 'co', 'chai...
# 29  1598337669515419649  ['statement', 'election', 'assistant', 'democr...

# %%
pd.read_csv(word_count_filename).head()
# Out:
#             handle     Word  Count
# 0  AustinScottGA08    today    496
# 1  AustinScottGA08    thank    361
# 2  AustinScottGA08  georgia    292
# 3  AustinScottGA08      day    276
# 4  AustinScottGA08     more    274
