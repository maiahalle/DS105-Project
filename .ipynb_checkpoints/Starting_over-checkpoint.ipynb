# %% [markdown]
# ### What I need to do is:
# - Make a list of republican handles and democrat handles from reptweets.csv
# - Use the lists to split df_word_count into a seperate word count dataframe for each party
# - Make visualisations based on each dataframe

# %%
import pandas as pd

# %%
acct_file = "reptweets.csv"
word_count_filename = "word_count.csv"
df_politicians = pd.read_csv(acct_file)
# csv file has trailing spaces on some column names, this insures there are no leading or trailing spaces
df_politicians.columns = df_politicians.columns.str.strip()
df_word_count = pd.read_csv(word_count_filename, low_memory=False)
# combines the two dataframes joining on the common handle column
df_party_word_count = pd.merge(df_politicians, df_word_count, how='inner', on='handle')
# get republicans
df_reps = df_party_word_count[df_party_word_count.party == 'R']
df_dems = df_party_word_count[df_party_word_count.party == 'D']
# get independants but only return the columns Word and Count
df_dem_words = df_party_word_count[df_party_word_count.party == 'D'][['Word', 'Count']]
df_rep_words = df_party_word_count[df_party_word_count.party == 'R'][['Word', 'Count']]

# %%
df_dem_sorted = df_dem_words.groupby(['Word']).sum().sort_values(by=["Count"], ascending = False)

# %%
df_rep_sorted = df_rep_words.groupby(['Word']).sum().sort_values(by=["Count"], ascending = False)

# %%
df_dem_sorted.head(50)
# Out:
#             Count
# Word
# today      106447
# work        96303
# more        90738
# act         77729
# need        76149
# community   75110
# make        74090
# help        74039
# family      72546
# year        63444
# get         62177
# health      58538
# support     51900
# pass        50680
# people      50475
# thank       47934
# day         47866
# right       46461
# time        45974
# bill        45366
# now         42683
# join        41414
# american    40585
# vote        39417
# care        38835
# protect     38782
# continue    35974
# fight       35326
# new         34311
# americans   33508
# take        32749
# house       31413
# proud       31166
# congress    30876
# country     30443
# life        30051
# here        28867
# trump       24363
# president   23624
# ensure      20600
# state       20163
# woman       19551
# great       17192
# keep        17076
# just        16333
# law         16183
# honor       15954
# so          15950
# see         15911
# service     15637

# %%
df_rep_sorted.head(50)
# Out:
#                 Count
# Word
# biden           71400
# today           70940
# more            68580
# work            53997
# thank           52027
# year            46845
# american        46818
# need            41374
# great           41157
# make            40830
# president       38185
# bill            37704
# family          36472
# day             35421
# border          34900
# join            33672
# support         33336
# americans       33196
# help            33010
# time            31570
# people          29686
# house           29139
# act             29038
# get             27906
# community       27411
# democrats       26805
# new             25609
# continue        25506
# now             24088
# state           23903
# here            23625
# america         23274
# life            19828
# country         19402
# nation          19385
# take            19259
# business        18123
# week            17966
# see             17733
# energy          17584
# honor           17091
# congress        16588
# proud           14376
# job             13311
# crisis          13099
# service         12795
# just            12714
# discuss         12253
# administration  12159
# national        11885

# %%
from plotnine import *

# %%
g_republicans = (
    ggplot(df_rep_sorted.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_republicans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\plotnine\mapping\evaluation.py:219, in evaluate(aesthetics, data, env)
#     218 try:
# --> 219     new_val = env.eval(col, inner_namespace=data)
#     220 except Exception as e:
#
# File ~\anaconda3\lib\site-packages\patsy\eval.py:165, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     164 code = compile(expr, source_name, "eval", self.flags, False)
# --> 165 return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                     + self._namespaces))
#
# File <string>:1, in <module>
#
# NameError: name 'Word' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~\anaconda3\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\anaconda3\lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\anaconda3\lib\site-packages\plotnine\ggplot.py:95, in ggplot.__repr__(self)
#      91 def __repr__(self):
#      92     """
#      93     Print/show the plot
#      94     """
# ---> 95     self.__str__()
#      96     return '<ggplot: (%d)>' % self.__hash__()
#
# File ~\anaconda3\lib\site-packages\plotnine\ggplot.py:86, in ggplot.__str__(self)
#      82 def __str__(self):
#      83     """
#      84     Print/show the plot
#      85     """
# ---> 86     self.draw(show=True)
#      88     # Return and empty string so that print(p) is "pretty"
#      89     return ''
#
# File ~\anaconda3\lib\site-packages\plotnine\ggplot.py:203, in ggplot.draw(self, return_ggplot, show)
#     201 self = deepcopy(self)
#     202 with plot_context(self, show=show):
# --> 203     self._build()
#     205     # setup
#     206     figure, axs = self._create_figure()
#
# File ~\anaconda3\lib\site-packages\plotnine\ggplot.py:289, in ggplot._build(self)
#     285 layout.setup(layers, self)
#     287 # Compute aesthetics to produce data with generalised
#     288 # variable names
# --> 289 layers.compute_aesthetics(self)
#     291 # Transform data using all scales
#     292 layers.transform(scales)
#
# File ~\anaconda3\lib\site-packages\plotnine\layer.py:67, in Layers.compute_aesthetics(self, plot)
#      65 def compute_aesthetics(self, plot):
#      66     for l in self:
# ---> 67         l.compute_aesthetics(plot)
#
# File ~\anaconda3\lib\site-packages\plotnine\layer.py:309, in layer.compute_aesthetics(self, plot)
#     301 def compute_aesthetics(self, plot):
#     302     """
#     303     Return a dataframe where the columns match the
#     304     aesthetic mappings.
#    (...)
#     307     expression evaluation are  made in here
#     308     """
# --> 309     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     310     evaled_aes = aes(**{col: col for col in evaled})
#     311     plot.scales.add_defaults(evaled, evaled_aes)
#
# File ~\anaconda3\lib\site-packages\plotnine\mapping\evaluation.py:221, in evaluate(aesthetics, data, env)
#     219     new_val = env.eval(col, inner_namespace=data)
#     220 except Exception as e:
# --> 221     raise PlotnineError(
#     222         _TPL_EVAL_FAIL.format(ae, col, str(e)))
#     224 try:
#     225     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'Word' (original error: name 'Word' is not defined)"
