# %% [markdown]
# ## Loading data:

# %%
import pandas as pd

# %%
df_republicans = pd.read_csv("republican_word_counts.csv")

# %%
df_republicans
# Out:
#                 Word  Count
# 0                 rt    332
# 1              biden    236
# 2             border    200
# 3                amp    197
# 4             family    137
# ...              ...    ...
# 2440          commun      1
# 2441  bipartisanship      1
# 2442            poll      1
# 2443          portal      1
# 2444             bud      1
#
# [2445 rows x 2 columns]

# %%
df_democrats = pd.read_csv("democrat_word_counts.csv")

# %%
df_democrats
# Out:
#             Word  Count
# 0            amp    284
# 1             rt    215
# 2          today    178
# 3           work    139
# 4            act    127
# ...          ...    ...
# 2172  possession      1
# 2173       potus      1
# 2174     estamos      1
# 2175  especially      1
# 2176           a      1
#
# [2177 rows x 2 columns]

# %% [markdown]
# ## Visualisations:

# %% [markdown]
# ### Bar graphs:

# %%
from plotnine import *

# %%
g_republicans = (
    ggplot(df_republicans.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip()
)

# %%
g_republicans
# Out:
# <ggplot: (177459410682)>

# %%
g_democrats = (
    ggplot(df_democrats.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip()
)

# %%
g_democrats
# Out:
# <ggplot: (177459401415)>

# %% [markdown]
# ### Word clouds:

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS

# %%
dtext = " ".join(i for i in df_democrats.Word)
dwordcloud = WordCloud(background_color="white").generate(dtext)
plt.figure( figsize=(15,10))
plt.imshow(dwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('democrats_word_cloud.png')

# %%
rtext = " ".join(i for i in df_republicans.Word)
rwordcloud = WordCloud(background_color="white").generate(rtext)
plt.figure( figsize=(15,10))
plt.imshow(rwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('republicans_word_cloud.png')

# %% [markdown]
# ## Loading more data:

# %%
df_republican_dates_tweets = pd.read_csv("republican_dates_tweets.csv")

# %%
df_republican_dates_tweets
# Out:
#       Unnamed: 0           handle                created_at  \
# 0             10  Robert_Aderholt  2022-12-06T21:43:15.000Z
# 1             11  Robert_Aderholt  2022-12-05T18:52:36.000Z
# 2             12  Robert_Aderholt  2022-11-29T23:49:59.000Z
# 3             13  Robert_Aderholt  2022-11-24T18:32:32.000Z
# 4             14  Robert_Aderholt  2022-11-18T19:52:26.000Z
# ...          ...              ...                       ...
# 1535        2975      RepNewhouse  2022-12-03T01:08:00.000Z
# 1536        2976      RepNewhouse  2022-12-02T21:19:00.000Z
# 1537        2977      RepNewhouse  2022-12-02T19:36:00.000Z
# 1538        2978      RepNewhouse  2022-12-01T22:47:00.000Z
# 1539        2979      RepNewhouse  2022-12-01T19:14:00.000Z
#
#                                              tweet_text
# 0     Great meeting @NASA Crew-3 astronauts Raja Cha...
# 1     What a view! It’ll be even better when our ast...
# 2     We must stand with the people of China in thei...
# 3     Rejoice always, pray continually, give thanks ...
# 4     I encourage you to take a look at my latest op...
# ...                                                 ...
# 1535  As a result of reckless government spending, e...
# 1536  Today we celebrate #WorldNuclearEnergyDay and ...
# 1537  Rainbow fentanyl continues to flood across our...
# 1538  🎄FYI!🎄\r\nChristmas tree permits are now avail...
# 1539  Washington apples are on shelves across Americ...
#
# [1540 rows x 4 columns]

# %%
text = " ".join(item for item in df_republican_dates_tweets['tweet_text'])

# %%
stopwords = set(STOPWORDS)
stopwords.update(["https", "RT", "t", "co", "amp", "will", "s", "U"])

# %%
wordcloud = WordCloud(background_color="white", stopwords = stopwords).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
df_democrat_keywords = pd.read_csv("democrat_keywords.csv")

# %%
df_democrat_keywords
# Out:
#       Unnamed: 0          handle                created_at  \
# 0              0        RepAdams  2022-12-07T00:20:49.000Z
# 1              1        RepAdams  2022-12-06T17:27:13.000Z
# 2              2        RepAdams  2022-12-06T15:53:19.000Z
# 3              3        RepAdams  2022-12-06T15:36:17.000Z
# 4              4        RepAdams  2022-12-06T15:08:44.000Z
# ...          ...             ...                       ...
# 1435        2995  DonaldNorcross  2022-12-05T19:31:13.000Z
# 1436        2996  DonaldNorcross  2022-12-05T17:00:01.000Z
# 1437        2997  DonaldNorcross  2022-12-05T16:14:28.000Z
# 1438        2998  DonaldNorcross  2022-12-05T14:07:26.000Z
# 1439        2999  DonaldNorcross  2022-12-03T15:00:00.000Z
#
#                                              tweet_text  \
# 0     RT @CCLCharlotteNC: Thanks to @RepAdams staff ...
# 1     RT @RepBonnie: SCOTUS will soon hear arguments...
# 2     RT @cspan: Congressional Gold Medal Ceremony f...
# 3     Congratulations @StephenCurry30! You’re always...
# 4     RT @CRLONLINE: .@RepAdams Introduces Bill to P...
# ...                                                 ...
# 1435  Every Republican in Congress should condemn th...
# 1436  I’m honored to help deliver this funding to ou...
# 1437  As the opioid epidemic rages on, a special int...
# 1438  On this day in history, the American Federatio...
# 1439  The rise in antisemitism reminds us to #NeverF...
#
#                                           key_word_list
# 0     ['rt', 'thank', 'staff', 'orlice', 'hodges', '...
# 1     ['rt', 'scotus', 'soon', 'hear', 'argument', '...
# 2     ['rt', 'congressional', 'gold', 'medal', 'cere...
# 3     ['congratulation', 'always', 'welcome', 'back'...
# 4     ['rt', 'introduce', 'bill', 'protect', 'essent...
# ...                                                 ...
# 1435  ['republican', 'congress', 'condemn', 'dangero...
# 1436  ['honor', 'help', 'deliver', 'funding', 'great...
# 1437  ['opioid', 'epidemic', 'rage', 'special', 'int...
# 1438  ['day', 'history', 'american', 'federation', '...
# 1439  ['rise', 'antisemitism', 'remind', 'neverforge...
#
# [1440 rows x 5 columns]

# %%
democrat_text = ''
for i in range(len(df_democrat_keywords)):
    democrat_text += ' ' + df_democrat_keywords.iloc[i]['key_word_list'].strip("[]").replace(',','').replace('\'', '').replace('amp', '').replace('rt', '')

# %%
democrat_text
# Out:
# '  thank staff orlice hodges avery bonifati meet today discuss climateac  scotus soon hear argument moore harper case threaten future free fair election justice tho  congressional gold medal ceremony january live am et c span congratulation always welcome back home  introduce bill protect essential workers wage garnishment systematic racism continue play role  introduce protect wages act protect family essential worker predatory debt collec propose new legislation protect family essential worker predatory debt collection practice read more protecting wages act here  excited announce pay spring media internship programs internship oppounity lo thank continue attention issue hudson pray moore county proud lifeline act provision adopt unlock affordable housing keep go charlotte still have housing crisis look forward work colleague make housing more affordable today honor law enforcement defend capitol build january congressional gold medal never forget bravery sacrifice defend democracy thank hero   house democrats
# 1539  Washington apples are on shelves across Americ...
#
# [1540 rows x 4 columns]

# %%
border_dates = []
for i in range(len(df_republican_dates_tweets)):
    if 'border' in df_republican_dates_tweets.iloc[i]['tweet_text']:
        border_dates.append(df_republican_dates_tweets.iloc[i]['created_at'])

# %%
border_dates
# Out:
# ['2022-11-17T00:31:51.000Z',
#  '2022-12-05T21:59:59.000Z',
#  '2022-11-29T14:58:13.000Z',
#  '2022-12-04T16:52:58.000Z',
#  '2022-12-02T23:58:15.000Z',
#  '2022-12-01T23:40:52.000Z',
#  '2022-12-01T17:39:18.000Z',
#  '2022-12-06T19:38:12.000Z',
#  '2022-12-06T19:08:44.000Z',
#  '2022-12-06T17:02:29.000Z',
#  '2022-12-06T16:28:31.000Z',
#  '2022-12-06T16:59:02.000Z',
#  '2022-12-06T20:35:01.000Z',
#  '2022-12-06T18:48:35.000Z',
#  '2022-12-06T15:01:22.000Z',
#  '2022-12-01T14:19:59.000Z',
#  '2022-12-06T20:16:06.000Z',
#  '2022-12-05T21:12:09.000Z',
#  '2022-12-06T20:45:58.000Z',
#  '2022-12-06T17:18:29.000Z',
#  '2022-12-06T18:05:46.000Z',
#  '2022-12-06T16:07:23.000Z',
#  '2022-12-06T21:39:24.000Z',
#  '2022-11-28T16:16:47.000Z',
#  '2022-12-02T15:59:05.000Z',
#  '2022-11-29T14:12:17.000Z',
#  '2022-12-06T17:08:00.000Z',
#  '2022-12-05T18:45:00.000Z',
#  '2022-12-03T17:09:44.000Z',
#  '2022-12-06T23:35:00.000Z',
#  '2022-12-02T16:05:10.000Z',
#  '2022-12-01T21:22:36.000Z',
#  '2022-12-01T19:27:04.000Z',
#  '2022-12-01T17:14:31.000Z',
#  '2022-11-28T19:04:05.000Z',
#  '2022-12-06T16:56:31.000Z',
#  '2022-12-02T15:25:26.000Z',
#  '2022-11-18T19:04:37.000Z',
#  '2022-12-06T18:26:42.000Z',
#  '2022-12-06T15:41:52.000Z',
#  '2022-12-06T14:10:53.000Z',
#  '2022-12-05T18:46:18.000Z',
#  '2022-11-22T21:45:54.000Z',
#  '2022-11-04T15:59:35.000Z',
#  '2022-12-06T16:12:56.000Z',
#  '2022-12-05T14:19:26.000Z',
#  '2022-11-28T19:59:43.000Z',
#  '2022-11-28T19:59:42.000Z',
#  '2022-12-06T22:32:26.000Z',
#  '2022-12-06T15:58:00.000Z',
#  '2022-12-06T20:55:44.000Z',
#  '2022-12-06T19:04:45.000Z',
#  '2022-12-06T16:30:14.000Z',
#  '2022-12-06T20:10:01.000Z',
#  '2022-12-01T15:04:09.000Z',
#  '2022-11-30T16:47:49.000Z',
#  '2022-12-04T19:52:00.000Z',
#  '2022-12-06T21:43:24.000Z',
#  '2022-12-06T20:07:10.000Z',
#  '2022-12-06T14:03:00.000Z',
#  '2022-12-05T20:06:00.000Z',
#  '2022-12-03T15:40:16.000Z',
#  '2022-12-03T14:53:03.000Z',
#  '2022-12-03T14:49:00.000Z',
#  '2022-12-01T21:42:47.000Z',
#  '2022-12-07T02:00:25.000Z',
#  '2022-12-06T22:47:13.000Z',
