# %% [markdown]
# ## Loading data:

# %%
import pandas as pd

# %%
import numpy as np

# %%
from PIL import Image

# %%
df_republicans = pd.read_csv("republican_word_counts.csv")

# %%
df_republicans
# Out:
#                 Word  Count
# 0                 rt    332
# 1              biden    236
# 2             border    200
# 3                amp    197
# 4             family    137
# ...              ...    ...
# 2440          commun      1
# 2441  bipartisanship      1
# 2442            poll      1
# 2443          portal      1
# 2444             bud      1
#
# [2445 rows x 2 columns]

# %%
df_democrats = pd.read_csv("democrat_word_counts.csv")

# %%
df_democrats
# Out:
#             Word  Count
# 0            amp    284
# 1             rt    215
# 2          today    178
# 3           work    139
# 4            act    127
# ...          ...    ...
# 2172  possession      1
# 2173       potus      1
# 2174     estamos      1
# 2175  especially      1
# 2176           a      1
#
# [2177 rows x 2 columns]

# %% [markdown]
# ## Visualisations:

# %% [markdown]
# ### Bar graphs:

# %%
from plotnine import *

# %%
g_republicans = (
    ggplot(df_republicans.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_republicans
# Out:
# <ggplot: (177464755643)>

# %%
g_democrats = (
    ggplot(df_democrats.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_democrats
# Out:
# <ggplot: (177468809581)>

# %% [markdown]
# ### Word clouds:

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS

# %%
dtext = " ".join(i for i in df_democrats.Word)
dwordcloud = WordCloud(background_color="white", scale=3).generate(dtext)
plt.figure( figsize=(15,10))
plt.imshow(dwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('democrats_word_cloud.png')

# %%
rtext = " ".join(i for i in df_republicans.Word)
rwordcloud = WordCloud(background_color="white", scale=3).generate(rtext)
plt.figure( figsize=(15,10))
plt.imshow(rwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('republicans_word_cloud.png')

# %% [markdown]
# ## Loading more data:

# %%
df_republican_dates_tweets = pd.read_csv("republican_dates_tweets.csv")

# %%
df_republican_dates_tweets
# Out:
#       Unnamed: 0           handle                created_at  \
# 0             10  Robert_Aderholt  2022-12-06T21:43:15.000Z
# 1             11  Robert_Aderholt  2022-12-05T18:52:36.000Z
# 2             12  Robert_Aderholt  2022-11-29T23:49:59.000Z
# 3             13  Robert_Aderholt  2022-11-24T18:32:32.000Z
# 4             14  Robert_Aderholt  2022-11-18T19:52:26.000Z
# ...          ...              ...                       ...
# 1535        2975      RepNewhouse  2022-12-03T01:08:00.000Z
# 1536        2976      RepNewhouse  2022-12-02T21:19:00.000Z
# 1537        2977      RepNewhouse  2022-12-02T19:36:00.000Z
# 1538        2978      RepNewhouse  2022-12-01T22:47:00.000Z
# 1539        2979      RepNewhouse  2022-12-01T19:14:00.000Z
#
#                                              tweet_text
# 0     Great meeting @NASA Crew-3 astronauts Raja Cha...
# 1     What a view! It’ll be even better when our ast...
# 2     We must stand with the people of China in thei...
# 3     Rejoice always, pray continually, give thanks ...
# 4     I encourage you to take a look at my latest op...
# ...                                                 ...
# 1535  As a result of reckless government spending, e...
# 1536  Today we celebrate #WorldNuclearEnergyDay and ...
# 1537  Rainbow fentanyl continues to flood across our...
# 1538  🎄FYI!🎄\r\nChristmas tree permits are now avail...
# 1539  Washington apples are on shelves across Americ...
#
# [1540 rows x 4 columns]

# %%
text = " ".join(item for item in df_republican_dates_tweets['tweet_text'])

# %%
stopwords = set(STOPWORDS)
stopwords.update(["https", "RT", "t", "co", "amp", "will", "s", "U"])

# %%
wordcloud = WordCloud(background_color="white", stopwords = stopwords, scale=3).generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
df_democrat_keywords = pd.read_csv("democrat_keywords.csv")

# %%
df_democrat_keywords
# Out:
#       Unnamed: 0          handle                created_at  \
# 0              0        RepAdams  2022-12-07T00:20:49.000Z
# 1              1        RepAdams  2022-12-06T17:27:13.000Z
# 2              2        RepAdams  2022-12-06T15:53:19.000Z
# 3              3        RepAdams  2022-12-06T15:36:17.000Z
# 4              4        RepAdams  2022-12-06T15:08:44.000Z
# ...          ...             ...                       ...
# 1435        2995  DonaldNorcross  2022-12-05T19:31:13.000Z
# 1436        2996  DonaldNorcross  2022-12-05T17:00:01.000Z
# 1437        2997  DonaldNorcross  2022-12-05T16:14:28.000Z
# 1438        2998  DonaldNorcross  2022-12-05T14:07:26.000Z
# 1439        2999  DonaldNorcross  2022-12-03T15:00:00.000Z
#
#                                              tweet_text  \
# 0     RT @CCLCharlotteNC: Thanks to @RepAdams staff ...
# 1     RT @RepBonnie: SCOTUS will soon hear arguments...
# 2     RT @cspan: Congressional Gold Medal Ceremony f...
# 3     Congratulations @StephenCurry30! You’re always...
# 4     RT @CRLONLINE: .@RepAdams Introduces Bill to P...
# ...                                                 ...
# 1435  Every Republican in Congress should condemn th...
# 1436  I’m honored to help deliver this funding to ou...
# 1437  As the opioid epidemic rages on, a special int...
# 1438  On this day in history, the American Federatio...
# 1439  The rise in antisemitism reminds us to #NeverF...
#
#                                           key_word_list
# 0     ['rt', 'thank', 'staff', 'orlice', 'hodges', '...
# 1     ['rt', 'scotus', 'soon', 'hear', 'argument', '...
# 2     ['rt', 'congressional', 'gold', 'medal', 'cere...
# 3     ['congratulation', 'always', 'welcome', 'back'...
# 4     ['rt', 'introduce', 'bill', 'protect', 'essent...
# ...                                                 ...
# 1435  ['republican', 'congress', 'condemn', 'dangero...
# 1436  ['honor', 'help', 'deliver', 'funding', 'great...
# 1437  ['opioid', 'epidemic', 'rage', 'special', 'int...
# 1438  ['day', 'history', 'american', 'federation', '...
# 1439  ['rise', 'antisemitism', 'remind', 'neverforge...
#
# [1440 rows x 5 columns]

# %%
democrat_text = ''
for i in range(len(df_democrat_keywords)):
    democrat_text += ' ' + df_democrat_keywords.iloc[i]['key_word_list'].strip("[]").replace(',','').replace('\'', '').replace('amp', '').replace('rt', '').replace('suppo', '')

# %%
democrat_text
# Out:
# '  thank staff orlice hodges avery bonifati meet today discuss climateac  scotus soon hear argument moore harper case threaten future free fair election justice tho  congressional gold medal ceremony january live am et c span congratulation always welcome back home  introduce bill protect essential workers wage garnishment systematic racism continue play role  introduce protect wages act protect family essential worker predatory debt collec propose new legislation protect family essential worker predatory debt collection practice read more protecting wages act here  excited announce pay spring media internship programs internship oppounity lo thank continue attention issue hudson pray moore county proud lifeline act provision adopt unlock affordable housing keep go charlotte still have housing crisis look forward work colleague make housing more affordable today honor law enforcement defend capitol build january congressional gold medal never forget bravery sacrifice defend democracy thank hero   house democrats understand latino community monolith use same talking point  right now kevin mccahy catch position have far flank tell never go story same so many latino community country proud welcome new leader join fight strengthen american dream  first time more decade house democrats have new leadership tomorrow talk wit statement condemn antisemitism today mark anniversary deadly terror attack devastate hometown san bernardino together honor memory people lose life keep family hea statement election chair co chairs democratic policy communications committee dpcc statement election assistant democratic leader take leave son bear family critical time family pay leave lead well outcome join new bipaisan paid leave caucus ensure family do same brave capitol police officer put risk deadly attack capitol january owe debt gratitude proud hero honor today congressional gold medal daca recipient veteran teacher health care worker small business owner represent so much make america great time now senate finally act homeishere  today texas democratic delegation meet celebrate honor legacy congresswoman johnson have aly so honored spend evening welcome holiday season annual holiday ball great news region contract create good pay job help noh texas lead manufacturing state a technology military tomorrow last day sign medicare next year impoant sta measure monthly cap insulin free vaccine go effect take advantage visit today make sure january never happen again do pass electoral count reform act protect democracy watch conversation folk last telephone town hall year begin join right now hear late work congress get answer question listen live call steady progress lower cost thank work congress americans now see real relief keep work ensure keep lower cost board today meet director atf division justice depament fellow task force member discuss concern rise ghost gun committed ensure illegal gun stay street hand dangerous individual look forward work next generation dem leadership excited have friend neighbor whipping vote spotifywrapped xi jinping covid policy catastrophe public health chinese society child paicular ccp listen brave protester follow science megalomania man happy smallbusinesssaturday teddy happy customer holiday shopping henry bear park newtonville  afford do year kevin mccahy engage showmanship  political theater deli happy thanksgiving office hope holiday spend love one city price curb manage demand send ukraine gray eagles military advantage outweigh legitimate concern security recommit make housing affordable work family angie sylling play crucial role here iowa battle raise awareness cancer offer affected family  resource find well treatment fight cure join honor as iowanoftheweek today high school student interview nomination attend prestigious united states military service academies thank passion  thank selection committee help young iowans pursue dream say atmar put life line field  troop  mission afghanistan now commi ...

# %%
dwc = WordCloud(background_color="white", scale=3).generate_from_text(democrat_text)
plt.figure( figsize=(15,10))
plt.imshow(dwc, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
democrat_mask = np.array(Image.open("C:/Users/Amara/Documents/DS105/Group_project/Images/democrat_donkey.jpg"))

# %%
dwc2 = WordCloud(background_color="white", mask=democrat_mask, max_words=200, scale=5).generate_from_text(democrat_text)
plt.figure( figsize=(10,15))
plt.imshow(dwc2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# contour_width=2, contour_color='black',

# %%
df_republican_keywords = pd.read_csv("republican_keywords.csv")

# %%
df_republican_keywords
# Out:
#       Unnamed: 0           handle                created_at  \
# 0             10  Robert_Aderholt  2022-12-06T21:43:15.000Z
# 1             11  Robert_Aderholt  2022-12-05T18:52:36.000Z
# 2             12  Robert_Aderholt  2022-11-29T23:49:59.000Z
# 3             13  Robert_Aderholt  2022-11-24T18:32:32.000Z
# 4             14  Robert_Aderholt  2022-11-18T19:52:26.000Z
# ...          ...              ...                       ...
# 1535        2975      RepNewhouse  2022-12-03T01:08:00.000Z
# 1536        2976      RepNewhouse  2022-12-02T21:19:00.000Z
# 1537        2977      RepNewhouse  2022-12-02T19:36:00.000Z
# 1538        2978      RepNewhouse  2022-12-01T22:47:00.000Z
# 1539        2979      RepNewhouse  2022-12-01T19:14:00.000Z
#
#                                              tweet_text  \
# 0     Great meeting @NASA Crew-3 astronauts Raja Cha...
# 1     What a view! It’ll be even better when our ast...
# 2     We must stand with the people of China in thei...
# 3     Rejoice always, pray continually, give thanks ...
# 4     I encourage you to take a look at my latest op...
# ...                                                 ...
# 1535  As a result of reckless government spending, e...
# 1536  Today we celebrate #WorldNuclearEnergyDay and ...
# 1537  Rainbow fentanyl continues to flood across our...
# 1538  🎄FYI!🎄\r\nChristmas tree permits are now avail...
# 1539  Washington apples are on shelves across Americ...
#
#                                           key_word_list
# 0     ['great', 'meeting', 'astronaut', 'raja', 'cha...
# 1     ['view', 'even', 'well', 'astronaut', 'get', '...
# 2     ['stand', 'people', 'china', 'protest', 'chine...
# 3     ['rejoice', 'always', 'pray', 'continually', '...
# 4     ['encourage', 'take', 'look', 'late', 'op', 'e...
# ...                                                 ...
# 1535  ['result', 'reckless', 'government', 'spending...
# 1536  ['today', 'celebrate', 'worldnuclearenergyday'...
# 1537  ['rainbow', 'fentanyl', 'continue', 'flood', '...
# 1538  ['fyi', 'christmas', 'tree', 'permit', 'now', ...
# 1539  ['washington', 'apple', 'shelf', 'america', 'f...
#
# [1540 rows x 5 columns]

# %%
republican_text = ''
for i in range(len(df_republican_keywords)):
    republican_text += ' ' + df_republican_keywords.iloc[i]['key_word_list'].strip("[]").replace(',','').replace('\'', '').replace('amp', '').replace('rt', '').replace('suppo', '')

# %%
republican_text
# Out:
# ' great meeting astronaut raja chari kayla barron thomas marshburn recent trip early year nasa lead mission space continue leadership crucial domain view even well astronaut get see aemis stand people china protest chinese communist pay rejoice always pray continually give thank circumstance god will christ jesus thessalonians encourage take look late op ed spacenews future american space exploration nasa space launch system pioneer new era human space presence come january new republican majority focus lower cost grocery gas secure border strengthen military hold biden administration accountable congratulation involve successful launch paicularly want thank historic moment mark beginning new era human presence permanence space aemis think else believe data back foxnew happy veterans day serve still serve army navy marines air force coast guard space force join wish happy bihday marine corps so many serve so proudly include cullman very own roy drinkard old living marine united states staff metter millen swainsboro tomorrow host community office hours need help federal agency drop more information visit member staff springfield sylvania tomorrow host community office hours need help federal agency drop more information visit staff alamo mount vernon sopeon tomorrow host community office hours need help federal agency drop more info  esg cancer capital market diminish investor return  deplete investment energy production jeopar  republican go war biden esg cancer deal federal agency difficult office here help need assistance federal matter member staff county week offer service appointment necessary full detail reminder application spring internship program available washington district only open week deadline apply next friday visit website more information k woh remember disgraced crypto giant ftx have stellar esg rating esg titan blackrock set record early year lose investor money just month read more air today pm tune channel listen live  instead get serious flip switch more energy production here help low proud attend nevada veterans memorial plaza grand opening  ribbon cutting plaza phenomenal place remember give prouder effo honor veteran happy thanksgiving great meeting builders association nohern nevada look forward continue collaboration building industry advance economic growth prosperity city town  today get ready renew push more education money next nevada legislature now republicans placer business alliance dc summit great meeting local regional business leader public official discussion focus lake tahoe impoance work together state line address challenge oppounity  nfrw member hi id or az nv ut  ca attend western conference stars  stipes vegas guest speaker congre lvrj repoer gary main thoughtful journalist nevada miss professionalism bring cover politic state rest peace gary honor veteransday come together commemorate nation hero owe veteran debt gratitude protect american freedom thank today day selfless devotion honor veteran annual dayton chamber veterans appreciation dinner thank service great country commitment freedom enjoy today americans  asa applaud fsgg subcmte rm send message colle congratulation friend mac schneider look forward work noh dakota agriculture have economic contribution  total job state grateful farmer rancher great receive update glad hear progress provide long term flood relief region met spirit lake nation chairman doug yankton discuss variety issue impoant tribe noh dakotans prepare farm bill top priority appreciated talk pia nd impoance crop insurance noh dakota grower   agree drill american oil create american job biden admin really good make really bad policy more duplicative red tape do keep air water clean  year ago today cpl christopher kleinwachter give life country kill action afghanista team have connection klieman coach bison win chionship year jim wacker coach ndsu head coach tcu noh dakota have more small business do so much good community smallbusinesssaturday great remi ...

# %%
rwc = WordCloud(background_color="white").generate_from_text(republican_text)
plt.imshow(rwc, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
republican_mask = np.array(Image.open("C:/Users/Amara/Documents/DS105/Group_project/Images/republican_elephant.jpg"))

# %%
rwc2 = WordCloud(background_color="white", mask=republican_mask, max_words=200, scale=3).generate_from_text(republican_text)
plt.figure( figsize=(10,15))
plt.imshow(rwc2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Time series stuff

# %%
# can't do much as only have 10 most recent tweets from each politician

# %%
df_republican_dates_tweets
# Out:
#       Unnamed: 0           handle                created_at  \
# 0             10  Robert_Aderholt  2022-12-06T21:43:15.000Z
# 1             11  Robert_Aderholt  2022-12-05T18:52:36.000Z
# 2             12  Robert_Aderholt  2022-11-29T23:49:59.000Z
# 3             13  Robert_Aderholt  2022-11-24T18:32:32.000Z
# 4             14  Robert_Aderholt  2022-11-18T19:52:26.000Z
# ...          ...              ...                       ...
# 1535        2975      RepNewhouse  2022-12-03T01:08:00.000Z
# 1536        2976      RepNewhouse  2022-12-02T21:19:00.000Z
# 1537        2977      RepNewhouse  2022-12-02T19:36:00.000Z
# 1538        2978      RepNewhouse  2022-12-01T22:47:00.000Z
# 1539        2979      RepNewhouse  2022-12-01T19:14:00.000Z
#
#                                              tweet_text
# 0     Great meeting @NASA Crew-3 astronauts Raja Cha...
# 1     What a view! It’ll be even better when our ast...
# 2     We must stand with the people of China in thei...
# 3     Rejoice always, pray continually, give thanks ...
# 4     I encourage you to take a look at my latest op...
# ...                                                 ...
# 1535  As a result of reckless government spending, e...
# 1536  Today we celebrate #WorldNuclearEnergyDay and ...
# 1537  Rainbow fentanyl continues to flood across our...
# 1538  🎄FYI!🎄\r\nChristmas tree permits are now avail...
# 1539  Washington apples are on shelves across Americ...
#
# [1540 rows x 4 columns]

# %%
border_dates = []
for i in range(len(df_republican_dates_tweets)):
    if 'border' in df_republican_dates_tweets.iloc[i]['tweet_text']:
        border_dates.append(df_republican_dates_tweets.iloc[i]['created_at'])

# %%
border_just_dates = []
for i in range(len(border_dates)):
    border_just_dates.append(border_dates[i][:11])

# %%
counts = []
for i in range(len(border_dates)):
    counts.append(1)

# %%
border_df = pd.DataFrame(list(zip(border_just_dates, counts)),
               columns =['Date', 'Count'])

# %%
grouped_border_df = border_df.groupby(['Date']).sum()

# %%
grouped_border_df
# Out:
#              Count
# Date
# 2022-02-07T      1
# 2022-02-08T      2
# 2022-08-21T      1
# 2022-11-03T      1
# 2022-11-04T      1
# 2022-11-14T      1
# 2022-11-17T      1
# 2022-11-18T      1
# 2022-11-22T      3
# 2022-11-23T      2
# 2022-11-28T      9
# 2022-11-29T      5
# 2022-11-30T      3
# 2022-12-01T     15
# 2022-12-02T      8
# 2022-12-03T      5
# 2022-12-04T      2
# 2022-12-05T     18
# 2022-12-06T     60
# 2022-12-07T      2

# %%
grouped_border_df.to_csv('C:/Users/Amara/Documents/GitHub/DS105-Project/grouped_border_df.csv')

# %%
df_grouped_border = pd.read_csv("grouped_border_df.csv")

# %%
df_grouped_border
# Out:
#            Date  Count
# 0   2022-02-07T      1
# 1   2022-02-08T      2
# 2   2022-08-21T      1
# 3   2022-11-03T      1
# 4   2022-11-04T      1
# 5   2022-11-14T      1
# 6   2022-11-17T      1
# 7   2022-11-18T      1
# 8   2022-11-22T      3
# 9   2022-11-23T      2
# 10  2022-11-28T      9
# 11  2022-11-29T      5
# 12  2022-11-30T      3
# 13  2022-12-01T     15
# 14  2022-12-02T      8
# 15  2022-12-03T      5
# 16  2022-12-04T      2
# 17  2022-12-05T     18
# 18  2022-12-06T     60
# 19  2022-12-07T      2

# %%
x_axis = [x for x in df_grouped_border['Date']]
y_axis = [x for x in df_grouped_border['Count']]

plt.plot(x_axis, y_axis)
plt.title('Plot showing the number of uses of the word \'border\' by republicans')
plt.xlabel('Date')
plt.ylabel('Number of uses')
plt.show()
