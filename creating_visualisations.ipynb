# %% [markdown]
# ## Loading data:

# %%
import pandas as pd

# %%
import numpy as np

# %%
from PIL import Image

# %%
df_republicans_initial = pd.read_csv("republican_word_counts.csv")

# %%
df_republicans_initial
# Out:
#                 Word  Count
# 0                 rt    332
# 1              biden    236
# 2             border    200
# 3                amp    197
# 4             family    137
# ...              ...    ...
# 2440          commun      1
# 2441  bipartisanship      1
# 2442            poll      1
# 2443          portal      1
# 2444             bud      1
#
# [2445 rows x 2 columns]

# %%
df_republicans = df_republicans_initial.drop(0).drop(3)

# %%
df_republicans
# Out:
#                 Word  Count
# 1              biden    236
# 2             border    200
# 4             family    137
# 5               more    129
# 6               have    105
# ...              ...    ...
# 2440          commun      1
# 2441  bipartisanship      1
# 2442            poll      1
# 2443          portal      1
# 2444             bud      1
#
# [2443 rows x 2 columns]

# %%
df_democrats_initial = pd.read_csv("democrat_word_counts.csv")

# %%
df_democrats_initial
# Out:
#             Word  Count
# 0            amp    284
# 1             rt    215
# 2          today    178
# 3           work    139
# 4            act    127
# ...          ...    ...
# 2172  possession      1
# 2173       potus      1
# 2174     estamos      1
# 2175  especially      1
# 2176           a      1
#
# [2177 rows x 2 columns]

# %%
df_democrats = df_democrats_initial.drop(0).drop(1)

# %%
df_democrats
# Out:
#             Word  Count
# 2          today    178
# 3           work    139
# 4            act    127
# 5         family    121
# 6           more    110
# ...          ...    ...
# 2172  possession      1
# 2173       potus      1
# 2174     estamos      1
# 2175  especially      1
# 2176           a      1
#
# [2175 rows x 2 columns]

# %% [markdown]
# ## Visualisations:

# %% [markdown]
# ### Bar graphs:

# %%
from plotnine import *

# %%
g_republicans = (
    ggplot(df_republicans.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_republicans
# Out:
# <ggplot: (120093084685)>

# %%
g_democrats = (
    ggplot(df_democrats.head(50), aes(x="Word",y="Count")) + geom_col() + coord_flip() + theme(figure_size=[9,8])
)

# %%
g_democrats
# Out:
# <ggplot: (120093460360)>

# %% [markdown]
# ### Word clouds:

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS

# %%
dtext = " ".join(i for i in df_democrats.Word)
dwordcloud = WordCloud(background_color="white", scale=3).generate(dtext)
plt.figure( figsize=(15,10))
plt.imshow(dwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('democrats_word_cloud.png')

# %%
rtext = " ".join(i for i in df_republicans.Word)
rwordcloud = WordCloud(background_color="white", scale=3).generate(rtext)
plt.figure( figsize=(15,10))
plt.imshow(rwordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
plt.savefig('republicans_word_cloud.png')

# %% [markdown]
# ## Loading more data:

# %%
df_republican_dates_tweets = pd.read_csv("republican_dates_tweets.csv")

# %%
df_republican_dates_tweets
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
text = " ".join(item for item in df_republican_dates_tweets['tweet_text'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tweet_text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.update(["https", "RT", "t", "co", "amp", "will", "s", "U"])

# %%
wordcloud = WordCloud(background_color="white", stopwords = stopwords, scale=3).generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
df_democrat_keywords = pd.read_csv("democrat_keywords.csv")

# %%
df_democrat_keywords

# %%
democrat_text = ''
for i in range(len(df_democrat_keywords)):
    democrat_text += ' ' + df_democrat_keywords.iloc[i]['key_word_list'].strip("[]").replace(',','').replace('\'', '').replace('amp', '').replace('rt', '').replace('suppo', '')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 democrat_text = ''
# ----> 2 for i in range(len(df_democrat_keywords)):
#       3     democrat_text += ' ' + df_democrat_keywords.iloc[i]['key_word_list'].strip("[]").replace(',','').replace('\'', '').replace('amp', '').replace('rt', '').replace('suppo', '')
#
# NameError: name 'df_democrat_keywords' is not defined

# %%
democrat_text
# Out:
# ''

# %%
dwc = WordCloud(background_color="white", scale=3).generate_from_text(democrat_text)
plt.figure( figsize=(15,10))
plt.imshow(dwc, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 dwc = WordCloud(background_color="white", scale=3).generate_from_text(democrat_text)
#       2 plt.figure( figsize=(15,10))
#       3 plt.imshow(dwc, interpolation='bilinear')
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:621, in WordCloud.generate_from_text(self, text)
#     604 """Generate wordcloud from text.
#     605
#     606 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618 self
#     619 """
#     620 words = self.process_text(text)
# --> 621 self.generate_from_frequencies(words)
#     622 return self
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:410, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
# ...

# %%
democrat_mask = np.array(Image.open("C:/Users/Amara/Documents/DS105/Group_project/Images/democrat_donkey.jpg"))

# %%
dwc2 = WordCloud(background_color="white", mask=democrat_mask, max_words=200, scale=5).generate_from_text(democrat_text)
plt.figure( figsize=(10,15))
plt.imshow(dwc2, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 dwc2 = WordCloud(background_color="white", mask=democrat_mask, max_words=200, scale=5).generate_from_text(democrat_text)
#       2 plt.figure( figsize=(10,15))
#       3 plt.imshow(dwc2, interpolation='bilinear')
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:621, in WordCloud.generate_from_text(self, text)
#     604 """Generate wordcloud from text.
#     605
#     606 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618 self
#     619 """
#     620 words = self.process_text(text)
# --> 621 self.generate_from_frequencies(words)
#     622 return self
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:410, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
# ...

# %%
# contour_width=2, contour_color='black',

# %%
df_republican_keywords = pd.read_csv("republican_keywords.csv")

# %%
df_republican_keywords
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
republican_text = ''
for i in range(len(df_republican_keywords)):
    republican_text += ' ' + df_republican_keywords.iloc[i]['key_word_list'].strip("[]").replace(',','').replace('\'', '').replace('amp', '').replace('rt', '').replace('suppo', '')

# %%
republican_text
# Out:
# ''

# %%
rwc = WordCloud(background_color="white").generate_from_text(republican_text)
plt.imshow(rwc, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 rwc = WordCloud(background_color="white").generate_from_text(republican_text)
#       2 plt.imshow(rwc, interpolation='bilinear')
#       3 plt.axis("off")
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:621, in WordCloud.generate_from_text(self, text)
#     604 """Generate wordcloud from text.
#     605
#     606 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618 self
#     619 """
#     620 words = self.process_text(text)
# --> 621 self.generate_from_frequencies(words)
#     622 return self
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:410, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     408 frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
# ...

# %%
republican_mask = np.array(Image.open("C:/Users/Amara/Documents/DS105/Group_project/Images/republican_elephant.jpg"))

# %%
rwc2 = WordCloud(background_color="white", mask=republican_mask, max_words=200, scale=3).generate_from_text(republican_text)
plt.figure( figsize=(10,15))
plt.imshow(rwc2, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 rwc2 = WordCloud(background_color="white", mask=republican_mask, max_words=200, scale=3).generate_from_text(republican_text)
#       2 plt.figure( figsize=(10,15))
#       3 plt.imshow(rwc2, interpolation='bilinear')
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:621, in WordCloud.generate_from_text(self, text)
#     604 """Generate wordcloud from text.
#     605
#     606 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618 self
#     619 """
#     620 words = self.process_text(text)
# --> 621 self.generate_from_frequencies(words)
#     622 return self
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:410, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
# ...

# %% [markdown]
# ## Time series stuff

# %%
# can't do much as only have 10 most recent tweets from each politician

# %%
df_republican_dates_tweets
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
border_dates = []
for i in range(len(df_republican_dates_tweets)):
    if 'border' in df_republican_dates_tweets.iloc[i]['tweet_text']:
        border_dates.append(df_republican_dates_tweets.iloc[i]['created_at'])

# %%
border_just_dates = []
for i in range(len(border_dates)):
    border_just_dates.append(border_dates[i][:10])

# %%
counts = []
for i in range(len(border_dates)):
    counts.append(1)

# %%
border_df = pd.DataFrame(list(zip(border_just_dates, counts)),
               columns =['Date', 'Count'])

# %%
grouped_border_df = border_df.groupby(['Date']).sum()

# %%
grouped_border_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
grouped_border_df.to_csv('C:/Users/Amara/Documents/GitHub/DS105-Project/grouped_border_df.csv')

# %%
df_grouped_border = pd.read_csv("grouped_border_df.csv")

# %%
df_grouped_border
# Out:
# Empty DataFrame
# Columns: [Date]
# Index: []

# %%
x_axis = [x for x in df_grouped_border['Date']]
y_axis = [x for x in df_grouped_border['Count']]

plt.plot(x_axis, y_axis)
plt.title('Plot showing the number of uses of the word \'border\' by republicans')
plt.xlabel('Date')
plt.ylabel('Number of uses')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_grouped_border.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 df_grouped_border.plot()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:327, in MPLPlot.generate(self)
#     325 def generate(self):
# ...

# %%
series = pd.read_csv("grouped_border_df.csv", header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
